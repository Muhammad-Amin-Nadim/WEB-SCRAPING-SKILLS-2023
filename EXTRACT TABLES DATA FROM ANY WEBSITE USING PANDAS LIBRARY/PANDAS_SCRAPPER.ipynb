# %%
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/Demographics_of_Pakistan"

# %%
df=pd.read_html(url)

# %%
len(df)
# Out:
# 33

# %%
df
# Out:
# [                             Demographics of Pakistan  \
#  0   Population pyramid of Pakistan as of July 1, 2021
#  1                                          Population
#  2                                             Density
#  3                                         Growth rate
#  4                                          Birth rate
#  5                                          Death rate
#  6                                     Life expectancy
#  7                                              • male
#  8                                            • female
#  9                                      Fertility rate
#  10                                 Net migration rate
#  11                                      Age structure
#  12                                         0–14 years
#  13                                        15–64 years
#  14                                        65 and over
#  15                                        Nationality
# ...

# %%
df[5]
# Out:
#     Province or Territory 1951[12] 1961[12] 1972[12] 1981[12] 1998[12] 2017[4]
# 0                  Punjab    17.3%    21.5%    24.4%    27.6%    31.3%   36.9%
# 1                   Sindh    29.2%    37.9%    40.4%    43.3%    48.8%   51.9%
# 2      Khyber Pakhtunkhwa     8.6%    10.3%    11.1%    12.6%    14.3%   16.5%
# 3             Balochistan    12.4%    16.9%    16.5%    15.6%    23.9%   27.6%
# 4                     ICT     0.0%     0.0%    32.3%    60.1%    65.7%   50.4%
# 5  Four Provinces and ICT    17.7%    22.5%    25.4%    28.3%    32.5%   36.4%
# 6         Azad Kashmir[5]        —        —        —     8.1%    12.5%   17.4%
# 7     Gilgit-Baltistan[6]        —        —        —        —    16.8%   16.5%
# 8                     ICT     0.0%     0.0%    32.3%    60.1%    65.7%   50.4%

# %%
df[10]
# Out:
#     Year Mid-yearpopulation Annuallive births Annualdeaths  \
#     Year Mid-yearpopulation Annuallive births Annualdeaths
# 0   1950           37696264           1647739      1173219
# 1   1951           38215785           1686378      1121858
# 2   1952           38816777           1727288      1089817
# 3   1953           39488228           1768524      1063098
# 4   1954           40224090           1810574      1044277
# ..   ...                ...               ...          ...
# 67  2017          216379655           6289965      1496276
# 68  2018          219731479           6302081      1508129
# 69  2019          223293280           6330933      1514600
# 70  2020          227196741           6362705      1606293
# 71  2021          231402117           6374741      1660400
#
#    Annualnaturalincrease   CBR   CDR   RNC    IMR   TFR Life expectancy
#    Annualnaturalincrease   CBR   CDR   RNC    IMR   TFR            Male Female
# ...

# %%
df[16]
# Out:
#                        0            1
# 0           Saudi Arabia      4000000
# 1   United Arab Emirates      1600000
# 2         United Kingdom      1200000
# 3          United States  600,410[97]
# 4                 Canada  215,000[98]
# 5                 Kuwait       190000
# 6           South Africa  180,000[99]
# 7                   Oman       385000
# 8              Australia  61,913[100]
# 9                Germany       179668
# 10                 Qatar        52500
# 11                France        50000
# 12                Norway  39,257[101]
# 13               Denmark        21000
# 14           New Zealand        10000
# 15               Ireland         9501

# %%
df[16].to_csv("country.csv")
